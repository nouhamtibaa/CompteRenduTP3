# %% [markdown]
# # Exercice1

# %%
import numpy as np
import matplotlib.pyplot as plt 

import pandas as pd  
import seaborn as sns

# %%
tp_nouha = pd.read_csv('grav.csv')
# Affichage de la taille du dataset (n_lignes and n_colonnes)
print("grav's shape : ", tp_nouha.shape) 
# Affichage des 10 premières lignes
tp_nouha.head()
# Out:
# grav's shape :  (7, 2)
#    height  seconds squared
# 0     100            8.967
# 1     120           11.989
# 2     150           15.852
# 3     180           16.991
# 4     200           20.284

# %%
#selection de la première colonne de notre dataset (la taille de la population)
X = tp_nouha.iloc[0:len(tp_nouha),0]
#selection de deuxième colonnes de notre dataset (le profit effectué)
Y = tp_nouha.iloc[0:len(tp_nouha),1]

# %%
axes = plt.axes()
axes.grid() 
# dessiner une grille pour une meilleur lisibilité du graphe
plt.scatter(X,Y) 
# X et Y sont les variables qu'on a extraite dans le paragraphe précédent
plt.show()

# %%
from scipy import stats

#linregress() renvoie plusieurs variables de retour. On s'interessera 

#particulierement au slope et intercept
slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
def predict(x):
   return slope * x + intercept

#la variable fitLine sera un tableau de valeurs prédites depuis la tableau de variables X
fitLine = predict(X)
plt.plot(X, fitLine, c='r')

# %%
np.corrcoef(X,Y)
# Out:
# array([[1.        , 0.99473243],
#        [0.99473243, 1.        ]])

# %%
from scipy import stats
stats.linregress(X,Y)
# Out:
# LinregressResult(slope=0.10280912511759172, intercept=-0.6801232361241745, rvalue=0.9947324344135698, pvalue=3.857021649169523e-06, stderr=0.004737919558962453)

# %% [markdown]
# # Exercice2

# %%
import numpy as np
import matplotlib.pyplot as plt 

import pandas as pd  
import seaborn as sns 

# %matplotlib inline

# %%
Student = pd.read_csv('test_scores.csv')
print("housing's shape:", Student.shape)
Student.head()
# Out:
# housing's shape: (2133, 11)
#   school  school_setting  school_type classroom  teaching_method  n_student  \
# 0  ANKYI             1.0          2.0       6OL              0.0       20.0
# 1  ANKYI             1.0          2.0       6OL              0.0       20.0
# 2  ANKYI             1.0          2.0       6OL              0.0       20.0
# 3  ANKYI             1.0          2.0       6OL              0.0       20.0
# 4  ANKYI             1.0          2.0       6OL              0.0       20.0
#
#   student_id  gender  lunch  pretest  posttest
# 0      2FHT3     1.0    2.0     62.0      72.0
# 1      3JIVH     1.0    2.0     66.0      79.0
# 2      3XOWE     0.0    2.0     64.0      76.0
# 3      556O0     1.0    2.0     61.0      77.0
# 4      74LOE     0.0    2.0     64.0      76.0

# %%
Y = Student ["posttest"]
X= Student["pretest"]

# %%
import matplotlib.pyplot as plt

axes= plt.axes()
axes.grid()
plt.scatter(X,Y)
plt.show()

# %%
from scipy import stats
slope, intercept, r_value,p_value, std_err = stats.linregress(X,Y)

# %%
from scipy import stats
slope, intercept, r_value,p_value, std_err = stats.linregress(X,Y)
def predict(x):
    return slope * x + intercept
fitLine = predict(X)
plt.plot(X, fitLine, c='r')

# %% [markdown]
# # Exercice3

# %% [markdown]
# # Import the data

# %%
dataset = pd.read_csv('housing.data.txt')

# %% [markdown]
# # checking dataset TXT

# %%
dataset.head(7)
# Out:
#       CIRM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# 5  0.02985   0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222.0
# 6  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2
# 5     18.7  394.12   5.21  28.7
# 6     15.2  395.60  12.43  22.9

# %% [markdown]
# # Data preprocessing

# %%
# check for missing values in all the columns
dataset.isnull().sum()
# Out:
# CIRM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# # checking columns and total records

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CIRM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null int64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null int64
# TAX        506 non-null float64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# MEDV       506 non-null float64
# dtypes: float64(12), int64(2)
# memory usage: 55.4 KB

# %% [markdown]
# # dataset description

# %%
dataset.describe()
# Out:
#              CIRM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     1.716290   11.363636   11.136779    0.069170    0.554695    6.284634
# std      2.653510   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.250895    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      2.326718   12.500000   18.100000    0.000000    0.624000    6.623500
# max      9.966540  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %% [markdown]
# # Exploring types of relationship across the entire dataset

# %%
sns.pairplot(dataset)

# %% [markdown]
# # Data Visualization (Target "MEDV" information)

# %%
sns.distplot(dataset['MEDV'],hist_kws=dict(edgecolor="black", linewidth=1),color='Blue')
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %% [markdown]
# # Displaying correlation among all the columns

# %%
dataset.corr()
# Out:
#              CIRM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CIRM     1.000000 -0.300774  0.590822  0.013922  0.634679 -0.190197  0.482013
# ZN      -0.300774  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.590822 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS     0.013922 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.634679 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.190197  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.482013 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.499501  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.838671 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.793392 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.362615 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# B       -0.377013  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# LSTAT    0.481907 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# MEDV    -0.362077  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# CIRM    -0.499501  0.838671  0.793392  0.362615 -0.377013  0.481907 -0.362077
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# MEDV     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %% [markdown]
# # Displaying correlation among all the columns using Heat Map

# %%
correlation_matrix = dataset.corr().round(2)
sns.heatmap(dataset.corr(), annot = True)

# %% [markdown]
# # Getting all Coulmn names

# %%
dataset.columns
# Out:
# Index(['CIRM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %% [markdown]
# # Columns as Features

# %%
X = dataset[['CIRM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
       'PTRATIO', 'B', 'LSTAT']]

# %% [markdown]
# # MEDV is my Target Variable, what we trying to predict

# %%
y = dataset['MEDV']

# %% [markdown]
# # Training the Model (Train=60% test=40%)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)



# splits the training and test data set in 80% : 20%
# assign random_state to any value.This ensures consistency.
#X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=5)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (303, 13)
# (203, 13)
# (303,)
# (203,)

# %% [markdown]
# # importing the Linear Regression Algorithm

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # creating LinearRegression Object

# %%
lm = LinearRegression()

# %% [markdown]
# # Training the Data Model

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# # Displaying the Intercept

# %%
print(lm.intercept_)
# Out:
# 39.81774410750467

# %% [markdown]
# # coefficient of variation

# %%
coeff_df = pd.DataFrame(lm.coef_, X.columns, columns=['Coefficient'])
coeff_df
# Out:
#          Coefficient
# CIRM       -0.190453
# ZN          0.039471
# INDUS       0.101345
# CHAS        4.223125
# NOX       -18.914617
# RM          2.950082
# AGE         0.016487
# DIS        -1.210472
# RAD         0.261479
# TAX        -0.011030
# PTRATIO    -0.870853
# B           0.007712
# LSTAT      -0.662778

# %% [markdown]
# # What is the value of R2 and the adjusted R2 ?

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
# model evaluation for training set

y_train_predict = lm.predict(X_train)
rmse = (np.sqrt(mean_squared_error(y_train, y_train_predict)))
r2 = r2_score(y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

# model evaluation for testing set

y_test_predict = lm.predict(X_test)
# root mean square error of the model
rmse = (np.sqrt(mean_squared_error(y_test, y_test_predict)))

# r-squared score of the model
r2 = r2_score(y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 4.285790048975232
# R2 score is 0.7474741874242252
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 5.503600020759893
# R2 score is 0.6906895443229648

# %% [markdown]
# # Predictions from our Model

# %%
predictions = lm.predict(X_test)
print(predictions)
# Out:
# [38.72444917 27.58140217 16.67116442 15.96978471 30.50972899 31.35985388
#  37.84713065  7.07745533 33.76290511  9.76441911 29.90226968 13.72044207
#  16.26984432 17.70685348 24.94003389 21.31269422  7.46375774 32.68033368
#  28.09333869 24.99574773 11.05017367 19.83679942 23.06914226 25.16165898
#  33.36292142 18.15905878 32.50755352 19.20284203 27.24300384 33.28211658
#  20.40172967 18.68443485 36.34367521 43.97673877 28.36078136 22.23573032
#  14.70268057 18.35098762  3.03130591 30.75974008 23.88301784 17.76784434
#  33.59725816 12.87926891 17.28488284 25.48326621 30.0150001  16.45959213
#  27.04688844 23.44989692 32.05105104 37.16220502 22.83471588 21.72339715
#  30.56023945 -0.88805911 19.71750715 16.42752633 23.60355189 21.14572724
#  29.66441605  2.65450498 16.56017279 19.58240877  9.5804101  24.29344535
#  24.31654217 19.77534732 17.37259095 19.84439661 23.77432628 21.80232466
#  23.34276763 20.7457581  27.95485385 21.05978171 37.08623939  7.6560312
#  29.0767978  17.12464823 15.63542049 18.71958523 29.70321582 15.96967125
#   9.84045023 21.38639057 22.28360694 32.05155322 22.22085746 21.02314282
#  11.48709265 10.22893481 22.56391886 31.9236738   7.01080305 34.17232007
#   6.72776984 31.59777634 12.80085669 21.22192451 32.48851103 21.29689841
#  27.18891495 25.0222946  22.79730257 24.72114689 24.89422465 30.17961705
#  36.80413367 32.56635701 23.26754076 35.71996626 24.25618904 21.97874219
#  29.68196802 26.92127417 28.81970714 30.91437631 26.59968133 28.64076929
#  15.2926808  20.92347361 21.83358825 36.9855049  25.027891   23.09744712
#  16.54872811  5.62752596 13.90930381 23.91252822 26.88241262 33.13970256
#  24.25942066 19.57249064 24.29339198 25.98063646 31.00813402 26.23532929
#  33.59145746 23.13379601 12.74080127 35.41625304 31.83060837 16.72887014
#  25.35855941 19.85304561 20.17542411 24.72967932 26.5763448  29.4288594
#  16.81261341 15.81346392 40.87329029 35.94448745 21.89305468 21.37929071
#  23.39874921 11.64124174 20.21536781 25.12465223 19.18034343 29.18613917
#  40.27174468 22.31352299 26.09263939 23.12391155 18.60291838 30.52176339
#  16.57651326 11.51559083 18.56460882 33.31309867 34.99610191 20.80632585
#   0.88341533 16.94101438 27.5054398  18.69447542 28.76645893 24.60491337
#  27.61929703 20.72599044 22.73540297 37.7824794  26.71288745 37.44846015
#  25.79444443 13.72148276 22.07742767 17.03494691 25.1908784  35.70318838
#   7.92155926 20.19411506 19.21528911 26.41153887 24.21640994 19.08311319
#  21.47609387 35.15634566 20.99365724 23.49275957 28.07720563]

# %%
# plotting the y_test vs y_pred
# ideally should have been a straight line
plt.scatter(y_test, predictions, edgecolor ='black')
plt.show()
